# %%
### Import packages ###
import itertools
import pandas as pd

# %% [markdown]
# # Input

# %%
# Input Data Set #
Data ="BostonHousing"
JobNameAbbrev = "BH"

# Input directory #
dir_path = "/Users/simondn/Documents/RashomonActiveLearning/Code/raw"

# Input Parameters #
ParameterDictionary = {"Data":[Data],
                       "Seed":list(range(0,100)),
                      #  "Seed":list([]),                       
                       "TestProportion":[0.2],
                       "CandidateProportion":[0.8],
                       "SelectorType":["GSxFunction"],
                       "ModelType":["LinearRegressionFunction"],
                       "UniqueErrorsInput": [0],
                       "n_estimators": [100], 
                       "regularization": [0.01],
                       "RashomonThresholdType": ["Adder"],                                         # ["Adder", "Multiplier"]
                       "RashomonThreshold": [0.11],
                       "Type": ["Regression"],
                       "Partition": ["compute"],    #compute                                                    # [short, medium, long, largemem, compute, cpu-g2-mem2x]
                       "Time": ["0:59:00"],                                                            # [00:59:00, 11:59:00, 6-23:59:00]
                       "Memory": ["100M"]}                                                                # [100M, 30000M, 100000M]

# Create Parameter Vector #
ParameterVector = pd.DataFrame.from_records(itertools.product(*ParameterDictionary.values()), columns=ParameterDictionary.keys())

# %% [markdown]
# # Include/exclude Passive Learning

# %%
# ### Include Random Forest ###
# RandomForestParameterDictionary = {"Data":[Data],
#                        "Seed":list([1, 4, 7, 11, 16, 20, 22, 26, 35, 38, 41, 45, 47, 51, 52, 54, 55, 57, 58, 59, 61, 70, 72, 74, 75, 77, 85, 88, 89, 91, 93, 98]),
#                        "TestProportion":[0.2],
#                        "CandidateProportion":[0.8],
#                        "SelectorType":["PassiveLearning"],
#                        "ModelType":["RandomForestClassificationFunction"],
#                        "UniqueErrorsInput": [1],
#                        "n_estimators": [100], 
#                        "regularization": [0.01],
#                        "RashomonThresholdType": ["Adder"],                                                    # ["Adder", "Multiplier"]
#                        "RashomonThreshold": [0],
#                        "Type": ["Classification"],
#                        "Partition": ["short"],                                                        # [short, medium, long, largemem, or compute]
#                        "Time": ["00:59:00"],                                                            # [00:59:00, 11:59:00, 6-23:59:00]
#                        "Memory": [1000]}                                                                # [1000, 30000, 100000]

# RandomForestParameterVector = pd.DataFrame.from_records(itertools.product(*RandomForestParameterDictionary.values()), columns=RandomForestParameterDictionary.keys())

# # NOTE: Comment out chunk to not include random forest simulations. ###
# ParameterVector = pd.concat([ParameterVector, RandomForestParameterVector]) # NOTE: Comment out to not include random forest baseline
# ParameterVector = ParameterVector.sort_values("Seed")
# ParameterVector.index = range(0, ParameterVector.shape[0])

# %% [markdown]
# # Include/exclude Random Forest Simulations

# %%
# ### Include Random Forest ###
# RandomForestParameterDictionary = {"Data":[Data],
#                        "Seed":list([1, 4, 7, 11, 16, 20, 22, 26, 35, 38, 41, 45, 47, 51, 52, 54, 55, 57, 58, 59, 61, 70, 72, 74, 75, 77, 85, 88, 89, 91, 93, 98]),
#                        "TestProportion":[0.2],
#                        "CandidateProportion":[0.8],
#                        "SelectorType":["TreeEnsembleQBCFunction"],
#                        "ModelType":["RandomForestClassificationFunction"],
#                        "UniqueErrorsInput": [0],
#                        "n_estimators": [100], 
#                        "regularization": [0.01],
#                        "RashomonThresholdType": ["Adder"],                                                    # ["Adder", "Multiplier"]
#                        "RashomonThreshold": [0],
#                        "Type": ["Classification"],
#                        "Partition": ["short"],                                                        # [short, medium, long, largemem, or compute]
#                        "Time": ["00:59:00"],                                                            # [00:59:00, 11:59:00, 6-23:59:00]
#                        "Memory": [1000]}                                                                # [1000, 30000, 100000]

# RandomForestParameterVector = pd.DataFrame.from_records(itertools.product(*RandomForestParameterDictionary.values()), columns=RandomForestParameterDictionary.keys())

# # NOTE: Comment out chunk to not include random forest simulations. ###
# ParameterVector = pd.concat([ParameterVector, RandomForestParameterVector]) # NOTE: Comment out to not include random forest baseline
# ParameterVector = ParameterVector.sort_values("Seed")
# ParameterVector.index = range(0, ParameterVector.shape[0])

# %% [markdown]
# # Job and Output Name

# %%
### Remove Dictionary ###
del ParameterDictionary

# Generate JobName #
ParameterVector["JobName"] = (
    ParameterVector["Seed"].astype(str) +
    JobNameAbbrev + 
    "_MT" + ParameterVector["ModelType"].astype(str) +
    "_UEI" + ParameterVector["UniqueErrorsInput"].astype(str) +
    "_" + ParameterVector["RashomonThresholdType"].astype(str) + 
    ParameterVector["RashomonThreshold"].astype(str))

# Replace Job Name #
ParameterVector["JobName"] = (
    ParameterVector["JobName"]
    .str.replace(r"_MTTreeFarmsFunction_UEI0_", "_D", regex=True)
    .str.replace(r"_MTTreeFarmsFunction_UEI1_", "_U", regex=True)
    .str.replace(r"Adder", "A", regex=True)
    .str.replace(r"Multiplier", "M", regex=True)
    .str.replace(r"_MTRandomForestClassificationFunction_UEI0_", "_RF", regex=True)
    .str.replace(r"_MTRandomForestClassificationFunction_UEI1_", "_PL", regex=True)
    )

# Output Name #
ParameterVector["Output"] = ParameterVector["Data"].astype(str) + "/" + ParameterVector["ModelType"].astype(str) + "/Raw/" + ParameterVector["JobName"] + ".pkl"
ParameterVector["Output"] = ParameterVector["Output"].str.replace("Function", "", regex=False)

# %%
ParameterVector
# Out:
#              Data  Seed  TestProportion  CandidateProportion SelectorType  \
# 0   BostonHousing     0             0.2                  0.8  GSxFunction
# 1   BostonHousing     1             0.2                  0.8  GSxFunction
# 2   BostonHousing     2             0.2                  0.8  GSxFunction
# 3   BostonHousing     3             0.2                  0.8  GSxFunction
# 4   BostonHousing     4             0.2                  0.8  GSxFunction
# ..            ...   ...             ...                  ...          ...
# 95  BostonHousing    95             0.2                  0.8  GSxFunction
# 96  BostonHousing    96             0.2                  0.8  GSxFunction
# 97  BostonHousing    97             0.2                  0.8  GSxFunction
# 98  BostonHousing    98             0.2                  0.8  GSxFunction
# 99  BostonHousing    99             0.2                  0.8  GSxFunction
#
#                    ModelType  UniqueErrorsInput  n_estimators  regularization  \
# 0   LinearRegressionFunction                  0           100            0.01
# 1   LinearRegressionFunction                  0           100            0.01
# 2   LinearRegressionFunction                  0           100            0.01
# 3   LinearRegressionFunction                  0           100            0.01
# 4   LinearRegressionFunction                  0           100            0.01
# ..                       ...                ...           ...             ...
# 95  LinearRegressionFunction                  0           100            0.01
# 96  LinearRegressionFunction                  0           100            0.01
# 97  LinearRegressionFunction                  0           100            0.01
# 98  LinearRegressionFunction                  0           100            0.01
# 99  LinearRegressionFunction                  0           100            0.01
#
#    RashomonThresholdType  RashomonThreshold        Type Partition     Time  \
# 0                  Adder               0.11  Regression   compute  0:59:00
# 1                  Adder               0.11  Regression   compute  0:59:00
# 2                  Adder               0.11  Regression   compute  0:59:00
# 3                  Adder               0.11  Regression   compute  0:59:00
# 4                  Adder               0.11  Regression   compute  0:59:00
# ..                   ...                ...         ...       ...      ...
# 95                 Adder               0.11  Regression   compute  0:59:00
# 96                 Adder               0.11  Regression   compute  0:59:00
# 97                 Adder               0.11  Regression   compute  0:59:00
# 98                 Adder               0.11  Regression   compute  0:59:00
# 99                 Adder               0.11  Regression   compute  0:59:00
#
#    Memory                                     JobName  \
# 0    100M   0BH_MTLinearRegressionFunction_UEI0_A0.11
# 1    100M   1BH_MTLinearRegressionFunction_UEI0_A0.11
# 2    100M   2BH_MTLinearRegressionFunction_UEI0_A0.11
# 3    100M   3BH_MTLinearRegressionFunction_UEI0_A0.11
# 4    100M   4BH_MTLinearRegressionFunction_UEI0_A0.11
# ..    ...                                         ...
# 95   100M  95BH_MTLinearRegressionFunction_UEI0_A0.11
# 96   100M  96BH_MTLinearRegressionFunction_UEI0_A0.11
# 97   100M  97BH_MTLinearRegressionFunction_UEI0_A0.11
# 98   100M  98BH_MTLinearRegressionFunction_UEI0_A0.11
# 99   100M  99BH_MTLinearRegressionFunction_UEI0_A0.11
#
#                                                Output
# 0   BostonHousing/LinearRegression/Raw/0BH_MTLinea...
# 1   BostonHousing/LinearRegression/Raw/1BH_MTLinea...
# 2   BostonHousing/LinearRegression/Raw/2BH_MTLinea...
# 3   BostonHousing/LinearRegression/Raw/3BH_MTLinea...
# 4   BostonHousing/LinearRegression/Raw/4BH_MTLinea...
# ..                                                ...
# 95  BostonHousing/LinearRegression/Raw/95BH_MTLine...
# 96  BostonHousing/LinearRegression/Raw/96BH_MTLine...
# 97  BostonHousing/LinearRegression/Raw/97BH_MTLine...
# 98  BostonHousing/LinearRegression/Raw/98BH_MTLine...
# 99  BostonHousing/LinearRegression/Raw/99BH_MTLine...
#
# [100 rows x 17 columns]

# %% [markdown]
# # Save Parameter Vector

# %%
### Resave ###

output_path = "/vscode/RashomonActiveLearning-1/Data/ParameterVectors" + str(Data) + ".csv"
ParameterVector.to_csv(output_path, index=False)
